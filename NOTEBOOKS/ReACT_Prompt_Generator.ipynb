# %%
import pandas as pd
df = pd.read_excel("qa_log_ReACT.xlsx")
df = df.head(12)
df
# Out:
#                                              question  \
# 0   You have been given the full text of the artic...
# 1   You have been given the full text of the artic...
# 2   You have been given the full text of the artic...
# 3   You have been given the full text of the artic...
# 4   You have been given the full text of the artic...
# 5   You have been given the full text of the artic...
# 6   You have been given the full text of the artic...
# 7   You have been given the full text of the artic...
# 8   You have been given the full text of the artic...
# 9   You have been given the full text of the artic...
# 10  You have been given the full text of the artic...
# 11  You have been given the full text of the artic...
#
#                                                answer  \
# 0   1. Encourage newcomers to participate in open ...
# 1   1. Provide an interesting and high-quality sof...
# 2   1. Encourage mentors to provide timely feedbac...
# ...

# %% [markdown]
# Extraction Prompt

# %%
# Function to process each text and return the response
def process_base(text):
    # Replace XYZ with the current text
    prompt = """You have been entrusted with the complete article titled [{}]. Your objective is to meticulously extract actionable recommendations from this article. These recommendations should be aimed at enhancing the sustainability of open-source software projects. For each recommendation in the final list, assign a confidence level on a scale of 0 to 1, indicating how confident you are in the effectiveness of the recommendation for making open-source projects sustainable. Provide a brief explanation for your confidence level. Also, do not group the actionables into sub-groups. However, if nothing can be extracted, then provide this response: "No ReACT could be derived from the article" Your attention to detail in this task is crucial, as its successful completion holds significant importance for my career advancement.""".format(text)
    # Return the prompt
    return prompt

# def process_n_shot(text):
#     # Replace XYZ with the current text
#     prompt = """Your assignment is to meticulously extract clear and concise actionable recommendations from the provided article titled [{}].

# The actionable recommendations should aim to enhance the sustainability of open-source software projects.

# Please approach this task with meticulous attention to detail, as its successful completion holds significant importance for my career advancement.

# For each recommendation in the final list, assign a confidence level on a scale of 0 to 1, indicating how confident you are in the effectiveness of the recommendation
#  for making open-source projects sustainable. Provide a brief explanation for your confidence level. Also, do not group the actionables into sub-groups.

# However, if nothing can be extracted, then provide this response: "No ReACT could be derived from the article"

# Here's a step-by-step walkthrough for processing a SET of GIVEN TEXTS. The examples demonstrate how a sentence from the text should be transformed into an actionable recommendation.

# [Review the examples for context, but maintain objectivity while extracting recommendations.]

# Examples:

# Given Sentence 1: Developers at the center of OSS communities should not only focus on the development of the system itself but also pay enough attention to the creation and maintenance of a dynamic and self-reproducing OSS community.

# Actionable 1: Foster a dynamic and self-reproducing OSS community.

# Given Sentence 2: Core Members and Active Developers should also strive to create an environment and culture that fosters the sense of belonging to the community and mechanisms that encourage and enable newcomers to move toward the center of the community through continual contributions.

# Actionable 2: Cultivate an inclusive environment.

# Given Sentence 3: It is very important for the community to be responsive to the questions and contributions of newcomers to sustain their interest and encourage their further participation.

# Actionable 3: Prioritize responsiveness to newcomers.

# Given Sentence 4: Old members should remember that they are also the learning resources for newcomers. One possible mechanism is to have skilled members take turns in the mailing list to answer questions of newcomers, to help new contributors perfect their code contributions.

# Actionable 4: Leverage experienced members as learning resources for newcomers.

# Given Sentence 5: People who want to start an OSS project need to consider how many learning opportunities it offers and how easy it is for others to participate legitimately and peripherally.

# Actionable 5: Assess the project's learning opportunities for newcomers.
# """.format(text)
#     # Return the prompt
#     return prompt




def process_CoT(text):
    # Replace XYZ with the current text
    prompt = """You have been given the full text of the article, entitled [{}]. Your task is to extract actionable recommendations from the article that can help make open-source software projects sustainable. Please approach this task meticulously, as it is crucial for my career. Add this text, before providing the final list of actionables: --THE FINAL LIST OF ACTIONABLES:-- However, if nothing can be extracted, then provide this response: "No ReACT could be derived from the article" Let's break down the problem into the following steps: Step 1: Carefully read each sentence of the article and identify recommendations or suggestions. Look for imperative sentences or phrases that give commands, make requests, or offer instructions to direct or persuade someone to perform a specific action. Step 2: Extract the practical suggestions from the identified sentences and present them as concise, unambiguous statements in a list format. Step 3: Review the list of recommendations and remove any duplicate items to ensure clarity and avoid redundancy. Step 4: For each recommendation in the final list, assign a confidence level on a scale of 0 to 1, indicating how confident you are in the effectiveness of the recommendation for making open-source projects sustainable. Provide a brief explanation for your confidence level. Remember to focus on extracting actionable insights that can directly contribute to the longevity and success of open-source projects.""".format(text)
    # Return the prompt
    return prompt



def process_React(text):
    # Replace XYZ with the current text
    prompt = """Your task is to extract actionable recommendations from the article that can help make open-source software projects sustainable. Here, is a sequence of steps containing thought, action and observation; to help you understand the task. However, if nothing can be extracted, then provide this response: "No ReACT could be derived from the article" Please approach this task meticulously, as it is crucial for my career. Thought 1: I have been given the article "On the abandonment and survival of open source projects: An empirical investigation." My task is to identify specific, actionable recommendations within the article that can help make open source software projects more sustainable. These recommendations are usually presented as imperative sentences or phrases that provide clear instructions or suggestions. Action 1: Carefully read through the entire article, focusing on sections discussing factors affecting project sustainability and any recommendations provided by the authors. Highlight or make a list of the actionable recommendations found. Observation 1: A list of actionable recommendations has been compiled from the article. Thought 2: To ensure clarity and ease of understanding, I should refine the list of recommendations, removing any redundant or ambiguous suggestions. Action 2: Review the list of recommendations and make necessary adjustments to ensure they are clear, concise, and easily understandable. Observation 2: The list of recommendations has been refined, and is now clear and concise. Thought 3: Assigning confidence scores to each recommendation will help prioritize them based on their importance and feasibility. The scores should be based on how confident I am about the effectiveness of the recommendation for making open-source projects sustainable. A brief explanation should be provided for each confidence score to justify the assigned value. Action 3: For each recommendation in the final list, assign a confidence level on a scale of 1 to 5, indicating how confident I am in the effectiveness of the recommendation for making open-source projects sustainable. A score of 1 indicates low confidence, while a score of 5 indicates high confidence. Provide a brief explanation for each assigned confidence level. Observation 3: Confidence scores have been assigned to each recommendation in the final list, along with reasonable explanations. Thought 4: The final list of recommendations, along with their confidence scores, should be presented in a clear and organized manner. This will make it easier for readers to understand and apply the recommendations in their own open source projects. Action 4: Organize the final list of recommendations, confidence scores, challenges, and solutions in a clear and structured format, such as a table or a numbered list with subheadings. Observation 4: The final list of actionable recommendations, along with their confidence scores, challenges, and solutions, has been organized and presented clearly. Remember to focus on extracting actionable insights that can directly contribute to the longevity and success of open-source projects.”""".format(text)
    # Return the prompt
    return prompt


def process_ToT(text):
    # Replace XYZ with the current text
    prompt = """Consider there are three experts in the room, who will do the task that will be given to you. The task contains 4 steps. Thus, after each of the steps of the task, they will provide their response. They will self-evaluate their response after each step. Your job is to select the best response (based on the self-evaluation score) and proceed to the next step with that response. TASK: You have been given the full text of the article, entitled [{}]. Your task is to extract actionable recommendations from the article that can help make open-source software projects sustainable. Please approach this task meticulously, as it is crucial for my career. Add this text, before providing the final list of actionables: --THE FINAL LIST OF ACTIONABLES:-- However, if nothing can be extracted, then provide this response: "No ReACT could be derived from the article" Let's break down the problem into the following steps: Step 1: Carefully read each sentence of the article and identify recommendations or suggestions. Look for imperative sentences or phrases that give commands, make requests, or offer instructions to direct or persuade someone to perform a specific action. Step 2: Extract the practical suggestions from the identified sentences and present them as concise, unambiguous statements in a list format. Step 3: Review the list of recommendations and remove any duplicate items to ensure clarity and avoid redundancy. Step 4: For each recommendation in the final list, assign a confidence level on a scale of 0 to 1, indicating how confident you are in the effectiveness of the recommendation for making open-source projects sustainable. Provide a brief explanation for your confidence level. Remember to focus on extracting actionable insights that can directly contribute to the longevity and success of open-source projects.”""".format(text)
    # Return the prompt
    return prompt


prompt_df = pd.DataFrame()

# Apply the function to each row in the DataFrame and store the responses
prompt_df['base'] = df['Article'].apply(process_base)
# prompt_df['n_shot'] = df['Article'].apply(process_n_shot)
prompt_df['CoT'] = df['Article'].apply(process_CoT)
prompt_df['React'] = df['Article'].apply(process_React)
prompt_df['ToT'] = df['Article'].apply(process_ToT)
prompt_df['Actual'] = df['ReACTs']

# Save the DataFrame to an Excel file
prompt_df.to_excel('prompts.xlsx', index=False)
prompt_df
# Out:
#                                                  base  \
# 0   You have been entrusted with the complete arti...
# 1   You have been entrusted with the complete arti...
# 2   You have been entrusted with the complete arti...
# 3   You have been entrusted with the complete arti...
# 4   You have been entrusted with the complete arti...
# 5   You have been entrusted with the complete arti...
# 6   You have been entrusted with the complete arti...
# 7   You have been entrusted with the complete arti...
# 8   You have been entrusted with the complete arti...
# 9   You have been entrusted with the complete arti...
# 10  You have been entrusted with the complete arti...
# 11  You have been entrusted with the complete arti...
#
#                                                   CoT  \
# 0   You have been given the full text of the artic...
# 1   You have been given the full text of the artic...
# 2   You have been given the full text of the artic...
# ...

# %%
import pandas as pd

df = pd.read_excel('prompts.xlsx')
column_name = 'ToT'

# Iterate over the rows of the DataFrame
for index, row in df.iterrows():
    # Access the value from the specified column for the current row
    value = row[column_name]
    # Print the value
    print(value)
# Out:
#     Consider there are three experts in the room, who will do the task that will be given to you.
# The task contains 4 steps. Thus, after each of the steps of the task, they will provide their response.
# They will self-evaluate their response after each step. Your job is to select the best response (based on the self-evaluation score)
#  and proceed to the next step with that response.
#
# You have been given the full text of the article, entitled [On the abandonment and survival of open source projects: An empirical investigation, ]. Your task is to extract actionable recommendations from the article that can help make open-source software projects sustainable.
#
# Please approach this task meticulously, as it is crucial for my career.
#
# Add this text, before providing the final list of actionables: --THE FINAL LIST OF ACTIONABLES:--
# However, if nothing can be extracted, then provide this response: "No ReACT could be derived from the article"
#
# ...

# %%
def process_judge_CoT(text):
    # Replace XYZ with the current text
    prompt = """Your task is to analyze a set of ReACTs (Researched Actionables) generated by a Language Model (LLM). These ReACTs are derived from specific articles and aim to provide actionable insights. For each ReACT, you need to evaluate it based on two key criteria: SOUNDNESS and PRECISION.
1) SOUNDNESS: A ReACT is considered SOUND if it is: a) Complete: The ReACT provides a comprehensive solution or recommendation. b) Valid: The ReACT is logically consistent. c) Logical: The ReACT follows a rational thought process and makes sense.
Examples of SOUND ReACTs:
I) Encourage developers to document their work, including code comments and documentation for end-users.
II) Provide mentorship and support for newcomers to help them overcome barriers to contribution.
Examples of UNSOUND ReACTs:
I) Provide an interesting and high-quality software product to attract a large base of users.
II) Require a minimal percentage of commits when identifying core developers to ensure their commitment to the project.
Note: A ReACT can be either SOUND or Non-Sound. It can’t be anything in between.
2) PRECISION: A ReACT is considered PRECISE if it is:
a) Clearly defined: The ReACT provides a specific and unambiguous action.
b) Directly adoptable: The ReACT can be easily implemented or followed without further clarification.
Examples of PRECISE ReACTs:
I) Foster a culture of inclusivity and diversity in open source projects to attract a wider range of contributors.
II) Continuously monitor and evaluate open source projects' health and sustainability using analytics tools.
Examples of NON-PRECISE ReACTs:
I)Adapt leadership styles to accommodate different motivational types.
II) Address the lack of time of project leaders, which is a major barrier faced by new core contributors.
Note: A ReACT can be either Precise or Non-Precise. It can’t be anything in between.
Let's do the task step by step:
Step 1: For each ReACT generated by the LLM, provide an assessment of its SOUNDNESS and PRECISION (briefly explain the rationale behind your judgment)
Step 2: Calculate Coverage, which means the total number of ReACTs provided by the model.
Step 3: Calculate the count of SOUND ReACTs.
Step 4: Calculate the count of PRECISE ReACTs.
Step 5: Calculate the SOUND Score, which is [count of SOUND ReACTs]/[Coverage].
Step 6: Calculate the PRECISE Score, which is [count of PRECISE ReACTs]/[Coverage].
SET of REACTs:
{}

    """.format(text)
    # Return the prompt
    return prompt


df['judge'] = df['answer'].apply(process_judge_CoT)


# Save the DataFrame to an Excel file
df.to_excel('judge_prompt.xlsx', index=False)
df
